# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer, FunctionTransformer
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
data=pd.read_csv("concrete_data.csv")
data.sample(5)
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 950    326.5                 0.0    137.9  199.0              10.8
# 946    149.5               236.0      0.0  175.8              12.6
# 514    424.0                22.0    132.0  168.0               8.9
# 1024   166.0               259.7      0.0  183.2              12.7
# 776    339.0                 0.0      0.0  185.0               0.0
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 950              801.1           792.5   28     38.63
# 946              846.8           892.7   28     32.96
# 514              822.0           750.0   56     74.36
# 1024             858.8           826.8   28     37.92
# 776             1069.0           754.0    7     21.16

# %%
data.replace(0.0,np.nan,inplace=True)

# %%
data.isnull().mean()*100
# Out:
# Cement                 0.000000
# Blast Furnace Slag    45.728155
# Fly Ash               54.951456
# Water                  0.000000
# Superplasticizer      36.796117
# Coarse Aggregate       0.000000
# Fine Aggregate         0.000000
# Age                    0.000000
# Strength               0.000000
# dtype: float64

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag     Fly Ash        Water  \
# count  1030.000000          559.000000  464.000000  1030.000000
# mean    281.167864          136.158676  120.288793   181.567282
# std     104.506364           72.351823   33.675470    21.354219
# min     102.000000           11.000000   24.500000   121.800000
# 25%     192.375000           95.000000   97.850000   164.900000
# 50%     272.900000          135.700000  121.400000   185.000000
# 75%     350.000000          189.000000  141.000000   192.000000
# max     540.000000          359.400000  200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count        651.000000       1030.000000     1030.000000  1030.000000
# mean           9.816897        972.918932      773.580485    45.662136
# std            4.580328         77.753954       80.175980    63.169912
# min            1.700000        801.000000      594.000000     1.000000
# 25%            6.950000        932.000000      730.950000     7.000000
# 50%            9.400000        968.000000      779.500000    28.000000
# 75%           11.600000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  559 non-null    float64
#  2   Fly Ash             464 non-null    float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    651 non-null    float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
data.corr()
# Out:
#                       Cement  Blast Furnace Slag   Fly Ash     Water  \
# Cement              1.000000           -0.344538 -0.377930 -0.081587
# Blast Furnace Slag -0.344538            1.000000  0.018471  0.232275
# Fly Ash            -0.377930            0.018471  1.000000 -0.058028
# Water              -0.081587            0.232275 -0.058028  1.000000
# Superplasticizer    0.363703            0.069789  0.053901 -0.538191
# Coarse Aggregate   -0.109349            0.012455 -0.017262 -0.182294
# Fine Aggregate     -0.222718           -0.227038 -0.173397 -0.450661
# Age                 0.081946           -0.043894 -0.008452  0.277618
# Strength            0.497832           -0.100259 -0.231618 -0.289633
#
#                     Superplasticizer  Coarse Aggregate  Fine Aggregate  \
# Cement                      0.363703         -0.109349       -0.222718
# Blast Furnace Slag          0.069789          0.012455       -0.227038
# Fly Ash                     0.053901         -0.017262       -0.173397
# Water                      -0.538191         -0.182294       -0.450661
# Superplasticizer            1.000000         -0.202265        0.207650
# Coarse Aggregate           -0.202265          1.000000       -0.178481
# Fine Aggregate              0.207650         -0.178481        1.000000
# Age                         0.009493         -0.003016       -0.156095
# Strength                    0.284473         -0.164935       -0.167241
#
#                          Age  Strength
# Cement              0.081946  0.497832
# Blast Furnace Slag -0.043894 -0.100259
# Fly Ash            -0.008452 -0.231618
# Water               0.277618 -0.289633
# Superplasticizer    0.009493  0.284473
# Coarse Aggregate   -0.003016 -0.164935
# Fine Aggregate     -0.156095 -0.167241
# Age                 1.000000  0.328873
# Strength            0.328873  1.000000

# %%
#handling outlier
colm=["Blast Furnace Slag","Fly Ash","Water","Superplasticizer","Fine Aggregate","Age"]
for x in colm:
    q3=data[x].quantile(0.75)
    q1=data[x].quantile(0.25)
    IQR=q3-q1
    upper_limit=q3+(1.5*IQR)
    lower_limit=q1-(1.5*IQR)
    data[x]=np.where(data[x]>upper_limit,upper_limit,np.where(data[x]<lower_limit,lower_limit,data[x]))

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag     Fly Ash        Water  \
# count  1030.000000          559.000000  464.000000  1030.000000
# mean    281.167864          136.010197  120.567619   181.543252
# std     104.506364           71.926875   32.906494    21.225052
# min     102.000000           11.000000   33.125000   124.250000
# 25%     192.375000           95.000000   97.850000   164.900000
# 50%     272.900000          135.700000  121.400000   185.000000
# 75%     350.000000          189.000000  141.000000   192.000000
# max     540.000000          330.000000  200.100000   232.650000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count        651.000000       1030.000000     1030.000000  1030.000000
# mean           9.557488        972.918932      773.439587    38.070388
# std            3.728667         77.753954       79.815303    35.782271
# min            1.700000        801.000000      594.000000     1.000000
# 25%            6.950000        932.000000      730.950000     7.000000
# 50%            9.400000        968.000000      779.500000    28.000000
# 75%           11.600000       1029.400000      824.000000    56.000000
# max           18.575000       1145.000000      963.575000   129.500000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
X=data.iloc[:,:-1]
Y=data["Strength"]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
x_train.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age'],
#       dtype='object')

# %%
def safe_log1p(X):
    X = X.astype(float)  # Ensure X is float
    return np.log1p(X, where=(X >= 0))

# Convert x_train and x_test to NumPy arrays if they are DataFrames
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.values
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.values

# %%
impu=ColumnTransformer([("Imputer",SimpleImputer(strategy="median"),[1, 2, 4])],remainder="passthrough")

# %%
functrans=ColumnTransformer([("function transf",FunctionTransformer(np.log1p),[5,6])],remainder="passthrough")

# %%
powtrans=ColumnTransformer([("power transfromer",PowerTransformer(method="yeo-johnson"),[0,2,3,7])],remainder="passthrough")

# %%
model_fit=LinearRegression()

# %%
pipe=Pipeline([("Imputation",impu),
               ("Function Transformer",functrans),
               ("Power Transformer", powtrans),
               ("Model training", model_fit)])

# %%
print(pipe)
# Out:
# Pipeline(steps=[('Imputation',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [1, 2, 4])])),
#                 ('Function Transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('function transf',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>),
#                                                   [5, 6])])),
#                 ('Power Transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('power transfromer',
#                                                   PowerTransformer(),
#                                                   [0, 2, 3, 7])])),
#                 ('Model training', LinearRegression())])

# %%
train_model=pipe.fit(x_train,y_train)

# %%
# After preprocessing
pred1=pipe.predict(x_test)
acu=r2_score(y_test,pred1)
acu
# Out:
# 0.7727418583474868

# %%
import pickle
with open("model31.pkl", "wb") as file:
    pickle.dump(pipe,file)
